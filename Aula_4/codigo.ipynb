# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/DSADM/Desktop/IABD_Inteligencia_Artificial_E_Big_Data/Aula_4/Base de dados/imigrantes_canada.csv')

# %%
df.head()

# %%
df.info()

# %% [markdown]
# Tratamento de dados

# %%
df.set_index(['País'],inplace=True) # Seta o index com a coluna Pais
anos = list(map(str,range(1980,2013))) # Converte os anos em string e armazena em uma lista

# %%
anos # exibe o conteúdo da variável

# %%
brasil = df.loc['Brasil',anos] # Pega os dados somente para o país

# %%
brasil

# %%
# Cria um dicionário com os dados do Brasil
brasil_dic = {
    'ano':brasil.index.tolist(),
    'imigrantes':brasil.values.tolist()
}

# %%
df_brasil = pd.DataFrame(brasil_dic) # Cria o dataframe

# %%
df_brasil

# %%
df_brasil.info()

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df_brasil['ano'],df_brasil['imigrantes'])
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'],fontsize=14) # Ajusta os valores para o eixo X
plt.yticks([500, 1000, 1500, 2000, 2500, 3000],fontsize=14)
plt.xlabel("Anos",fontsize=14)
plt.title("Imigração do Brasil para o Canadá",fontsize=14)
plt.ylabel("Número de Imigrantes",fontsize=14)
plt.show()

# %%
argentina = df.loc['Argentina',anos]

# %%
argentina

# %%
argentina_dic = {
    'ano':argentina.index.tolist(),
    'imigrantes':argentina.values.tolist()
}

# %%
df_argentina = pd.DataFrame(argentina_dic)

# %%
df_argentina

# %%
df_argentina.info()

# %%
plt.plot(df_argentina['ano'],df_argentina['imigrantes'])
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'],fontsize=14) # Ajusta os valores para o eixo X
plt.yticks([500, 1000, 1500, 2000, 2500, 3000],fontsize=14)
plt.xlabel("Anos",fontsize=14)
plt.title("Imigração da Argentina para o Canadá",fontsize=14)
plt.ylabel("Número de Imigrantes",fontsize=14)
plt.show()

# %%
plt.plot(df_brasil['ano'],df_brasil['imigrantes'], label='Brasil')
plt.plot(df_argentina['ano'],df_argentina['imigrantes'], label='Argentina')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'],fontsize=14) # Ajusta os valores para o eixo X
plt.yticks([500, 1000, 1500, 2000, 2500, 3000],fontsize=14)
plt.xlabel("Anos",fontsize=14)
plt.title("Imigração da Argentina para o Canadá",fontsize=14)
plt.ylabel("Número de Imigrantes",fontsize=14)
plt.show()

# %%
df_comparacao = df.loc[['Brasil', 'Argentina'],anos] # Pega duas colunas Brasil e Argentina

# %%
df_comparacao = df_comparacao.T # Matriz transposta

# %%
df_comparacao.head()

# %%
df_comparacao['Total'] = df_comparacao['Brasil']+df_comparacao['Argentina'] # Soma duas colunas do dataframe

# %%
plt.figure(figsize=(10,8))
plt.plot(df_comparacao['Brasil'],label = 'Brasil',color='blue')
plt.plot(df_comparacao['Argentina'],label = 'Argentina',color='red')
plt.plot(df_comparacao['Total'],label='Total',color='black')
plt.legend(loc='upper left')
plt.title('Comparação de imigrantes do Brasil para o Canadá \n e da Argentina para o Canadá')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'], fontsize=14)
plt.yticks([500, 1000, 1500, 2000, 2500, 3000], fontsize=14)
plt.ylabel('Número de imigrantes', fontsize=14)
plt.xlabel('Ano', fontsize=14)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4)) # Criando uma figura

ax.plot(df_brasil['ano'],df_brasil['imigrantes'],lw=3,color='green') # Comando
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) # Altera o intervalo do eixo X
ax.xaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)
ax.grid(linestyle='--')
ax.set_title('Imigração do Brasil para o Canadá \n 1980 a 2013',loc='left')
ax.set_xlabel('Ano',fontsize=14)
ax.set_ylabel('Nº de imigrantes',fontsize=14)
plt.show()

# %%
# Cria a figura
fig, axs = plt.subplots(1,2,figsize=(15,5))

# Subplot 1: Gráfico de linhas
axs[0].plot(df_brasil['ano'], df_brasil['imigrantes'])
axs[0].set_title('Imigração do Brasil para o Canadá \n 1980 a 2013')
axs[0].set_xlabel('Ano')
axs[0].set_ylabel('Número de imigrantes')

axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))
axs[0].grid()
#Subplot 2: Boxplot
axs[1].boxplot(df_brasil['imigrantes'])
axs[1].set_title('Box-plot da imigração do Brasil para o Canadá\n 1980 a 2013')
axs[1].set_xlabel('Brasil')
axs[1].set_ylabel('Número de imigrantes')
axs[1].grid()

# %%
df_brasil.describe()
# Out:
#         imigrantes
# count    33.000000
# mean    846.818182
# std     656.540481
# min     130.000000
# 25%     394.000000
# 50%     650.000000
# 75%     969.000000
# max    2598.000000
